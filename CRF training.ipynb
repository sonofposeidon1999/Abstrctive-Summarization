# %%
import sys
from collections import namedtuple
import csv
import glob
import os
import pycrfsuite

def get_utterances_from_file(dialog_csv_file, dialog_csv_filename):
    reader = csv.DictReader(dialog_csv_file)
    path = dialog_csv_filename.split("\\")
    return [_dict_to_dialog_utterance(du_dict, path[-1]) for du_dict in reader]

def get_utterances_from_filename(dialog_csv_filename):
    with open(dialog_csv_filename, "r") as dialog_csv_file:
        return get_utterances_from_file(dialog_csv_file, dialog_csv_filename)

def get_data(data_dir):
    dialog_filenames = sorted(glob.glob(os.path.join(data_dir, "*.csv")))
    for dialog_filename in dialog_filenames:
        yield get_utterances_from_filename(dialog_filename)

DialogUtterance = namedtuple("DialogUtterance", ("act_tag", "speaker", "pos", "text", "fileName"))

PosTag = namedtuple("PosTag", ("token", "pos"))

def _dict_to_dialog_utterance(du_dict, dialog_csv_filename):

    # Remove anything with
    for k, v in du_dict.items():
        if len(v.strip()) == 0:
            du_dict[k] = None

    # Extract tokens and POS tags
    if du_dict["pos"]:
        du_dict["pos"] = [
            PosTag(*token_pos_pair.split("/"))
            for token_pos_pair in du_dict["pos"].split()]
    du_dict["fileName"] = dialog_csv_filename
    return DialogUtterance(**du_dict)

def createFeatureList(files):
    xTrain = []
    yTrain = []
    fileNames = []
    for utterances in files:
        file = []
        labels = []
        first = True
        speaker = ''
        for dialogUtterance in utterances:
            fileName = dialogUtterance.fileName
            feature = []
            labels.append(dialogUtterance.act_tag)
            if first:
                feature.append('1')
                feature.append('0')
                speaker = dialogUtterance.speaker
                first = False
            else:
                feature.append('0')
                if dialogUtterance.speaker == speaker:
                    feature.append('0')
                else:
                    feature.append('1')
                    speaker = dialogUtterance.speaker
            if dialogUtterance.pos:
                for posTag in dialogUtterance.pos:
                    feature.append("TOKEN_"+posTag.token)
                for posTag in dialogUtterance.pos:
                    feature.append("POS_"+posTag.pos)
            file.append(feature)
        xTrain.append(file)
        yTrain.append(labels)
        fileNames.append(fileName)
    return xTrain, yTrain, fileNames


trainDir = 'C:/Users/91908/Desktop/Dream Hokage/Sem-6/Mini Project/SequenceLabelingWithCRF-master/train'
devDir = 'C:/Users/91908/Desktop/Dream Hokage/Sem-6/Mini Project/SequenceLabelingWithCRF-master/dev'
outputFile = 'C:/Users/91908/Desktop/Dream Hokage/Sem-6/Mini Project/SequenceLabelingWithCRF-master/output.txt'


# get all utterances
files_train = get_data(trainDir)
files_test = get_data(devDir)

# create feature list
xTrain, yTrain, filenames_train = createFeatureList(files_train)
xTest, yTest, filenames_test = createFeatureList(files_test)


# train crf model
trainer = pycrfsuite.Trainer(verbose=False)

for xseq, yseq in zip(xTrain, yTrain):
    trainer.append(xseq, yseq)

trainer.set_params({
    'c1': 1.0,   # coefficient for L1 penalty
    'c2': 1e-3,  # coefficient for L2 penalty
    'max_iterations': 150,  # stop earlier

    # include transitions that are possible, but not observed
    'feature.possible_transitions': True
})

trainer.params()
trainer.train('baseline_model.crfsuite')

# test on dev data
tagger = pycrfsuite.Tagger()
tagger.open('baseline_model.crfsuite')

yPred = [tagger.tag(xseq) for xseq in xTest]

#print(yPred)
#print(yTest)

correctCount = 0
count = 0
# write output file
fileHandler = open(outputFile, "w")
for i in range(0, len(yPred)):
    fileHandler.write("Filename=\""+filenames_test[i]+"\"\n")
    for j in range (0, len(yPred[i])):
        fileHandler.write(yPred[i][j]+"\n")
        if yPred[i][j] == yTest[i][j]:
            correctCount += 1
        count += 1
    fileHandler.write("\n")
fileHandler.close()

# %%
import sys
import csv
import glob
import os

def getLabelData(testDir):
    fileMap = {}
    dialog_filenames = sorted(glob.glob(os.path.join(testDir, "*.csv")))
    for dialog_filename in dialog_filenames:
        with open(dialog_filename,"r") as f:
            labels = []
            reader = csv.reader(f,delimiter = ",")
            data = list(reader)
            for row in data[1:]:
                labels.append(row[0])
            path = dialog_filename.split("\\")
            fileMap[path[-1]] = labels

    return fileMap

def getOutputLabels(outputFile):
    fileHandler = open(outputFile, "r")
    lines = fileHandler.readlines()
    fileMap = {}
    labels = []
    for line in lines:
        if "Filename=" in line:
            fileName = line.replace("Filename=\"","").replace("\"","").strip()
            labels = []
            fileMap[fileName] = labels
        elif line.strip() not in "":
            labels.append(line.strip())

    return fileMap


print ('Argument count : ', len(sys.argv))
#exit if file name is not provided as command line argument
if len(sys.argv) != 3:
    print ('Please send file name as command line argument')
    exit(0)

devDir = 'C:/Users/91908/Desktop/Dream Hokage/Sem-6/Mini Project/SequenceLabelingWithCRF-master/dev'
outputFile = 'C:/Users/91908/Desktop/Dream Hokage/Sem-6/Mini Project/SequenceLabelingWithCRF-master/output1.txt'

# get actual file names and labels
print ('devDir : ', devDir,' outputFile : ', outputFile)
fileMap = getLabelData(devDir)

# get file nmaes and labels from output.txt
outputFileMap = getOutputLabels(outputFile)

# count incorrect and total labels
incorrect = 0
total = 0
for key in fileMap.keys():
    acutalLabels = fileMap[key]
    predictedLabels = outputFileMap[key]
    wrong = 0
    total += len(acutalLabels)
    for label1, label2 in zip(acutalLabels, predictedLabels):
        if label1 != label2:
            wrong += 1
    incorrect += wrong
    print(key+" has "+str(wrong)+" incorrect labels and "+str((len(acutalLabels)-len(predictedLabels)))+" missing labels")

print("total label = "+str(total))
print("total incorrect = "+str(incorrect))

accuracy = ((total - incorrect)/total)*100
print("Accuracy = "+str(accuracy))
# Out:
# Argument count :  3
# devDir :  C:/Users/91908/Desktop/Dream Hokage/Sem-6/Mini Project/SequenceLabelingWithCRF-master/dev  outputFile :  C:/Users/91908/Desktop/Dream Hokage/Sem-6/Mini Project/SequenceLabelingWithCRF-master/output1.txt
# 0808.csv has 19 incorrect labels and 0 missing labels
# 0809.csv has 25 incorrect labels and 0 missing labels
# 0810.csv has 32 incorrect labels and 0 missing labels
# 0811.csv has 45 incorrect labels and 0 missing labels
# 0812.csv has 13 incorrect labels and 0 missing labels
# 0813.csv has 51 incorrect labels and 0 missing labels
# 0814.csv has 38 incorrect labels and 0 missing labels
# 0815.csv has 29 incorrect labels and 0 missing labels
# 0816.csv has 61 incorrect labels and 0 missing labels
# 0817.csv has 45 incorrect labels and 0 missing labels
# 0818.csv has 58 incorrect labels and 0 missing labels
# 0819.csv has 39 incorrect labels and 0 missing labels
# 0820.csv has 30 incorrect labels and 0 missing labels
# 0821.csv has 74 incorrect labels and 0 missing labels
# 0822.csv has 42 incorrect labels and 0 missing labels
# 0823.csv has 38 incorrect labels and 0 missing labels
# 0824.csv has 75 incorrect labels and 0 missing labels
# 0825.csv has 71 incorrect labels and 0 missing labels
# 0826.csv has 77 incorrect labels and 0 missing labels
# 0827.csv has 33 incorrect labels and 0 missing labels
# 0828.csv has 33 incorrect labels and 0 missing labels
# 0829.csv has 56 incorrect labels and 0 missing labels
# 0830.csv has 76 incorrect labels and 0 missing labels
# 0831.csv has 55 incorrect labels and 0 missing labels
# 0832.csv has 28 incorrect labels and 0 missing labels
# 0833.csv has 36 incorrect labels and 0 missing labels
# 0834.csv has 43 incorrect labels and 0 missing labels
# 0835.csv has 51 incorrect labels and 0 missing labels
# 0836.csv has 51 incorrect labels and 0 missing labels
# 0837.csv has 78 incorrect labels and 0 missing labels
# 0838.csv has 13 incorrect labels and 0 missing labels
# 0839.csv has 31 incorrect labels and 0 missing labels
# 0840.csv has 37 incorrect labels and 0 missing labels
# 0841.csv has 27 incorrect labels and 0 missing labels
# 0842.csv has 43 incorrect labels and 0 missing labels
# 0843.csv has 56 incorrect labels and 0 missing labels
# 0844.csv has 32 incorrect labels and 0 missing labels
# 0845.csv has 20 incorrect labels and 0 missing labels
# 0846.csv has 32 incorrect labels and 0 missing labels
# 0847.csv has 37 incorrect labels and 0 missing labels
# 0848.csv has 126 incorrect labels and 0 missing labels
# 0849.csv has 90 incorrect labels and 0 missing labels
# 0850.csv has 38 incorrect labels and 0 missing labels
# 0851.csv has 36 incorrect labels and 0 missing labels
# 0852.csv has 104 incorrect labels and 0 missing labels
# 0853.csv has 34 incorrect labels and 0 missing labels
# 0854.csv has 34 incorrect labels and 0 missing labels
# 0855.csv has 34 incorrect labels and 0 missing labels
# 0856.csv has 82 incorrect labels and 0 missing labels
# 0857.csv has 71 incorrect labels and 0 missing labels
# 0858.csv has 46 incorrect labels and 0 missing labels
# 0859.csv has 67 incorrect labels and 0 missing labels
# 0860.csv has 71 incorrect labels and 0 missing labels
# 0861.csv has 53 incorrect labels and 0 missing labels
# 0862.csv has 54 incorrect labels and 0 missing labels
# 0863.csv has 38 incorrect labels and 0 missing labels
# 0864.csv has 37 incorrect labels and 0 missing labels
# 0865.csv has 24 incorrect labels and 0 missing labels
# 0866.csv has 61 incorrect labels and 0 missing labels
# 0867.csv has 49 incorrect labels and 0 missing labels
# 0868.csv has 24 incorrect labels and 0 missing labels
# 0869.csv has 76 incorrect labels and 0 missing labels
# 0870.csv has 67 incorrect labels and 0 missing labels
# 0871.csv has 57 incorrect labels and 0 missing labels
# 0872.csv has 70 incorrect labels and 0 missing labels
# 0873.csv has 18 incorrect labels and 0 missing labels
# 0874.csv has 82 incorrect labels and 0 missing labels
# 0875.csv has 42 incorrect labels and 0 missing labels
# 0876.csv has 41 incorrect labels and 0 missing labels
# 0877.csv has 31 incorrect labels and 0 missing labels
# 0878.csv has 48 incorrect labels and 0 missing labels
# 0879.csv has 48 incorrect labels and 0 missing labels
# 0880.csv has 61 incorrect labels and 0 missing labels
# 0881.csv has 21 incorrect labels and 0 missing labels
# 0882.csv has 64 incorrect labels and 0 missing labels
# 0883.csv has 74 incorrect labels and 0 missing labels
# 0884.csv has 60 incorrect labels and 0 missing labels
# 0885.csv has 34 incorrect labels and 0 missing labels
# 0886.csv has 27 incorrect labels and 0 missing labels
# 0887.csv has 42 incorrect labels and 0 missing labels
# 0888.csv has 35 incorrect labels and 0 missing labels
# 0889.csv has 72 incorrect labels and 0 missing labels
# 0890.csv has 31 incorrect labels and 0 missing labels
# 0891.csv has 52 incorrect labels and 0 missing labels
# 0892.csv has 50 incorrect labels and 0 missing labels
# 0893.csv has 43 incorrect labels and 0 missing labels
# 0894.csv has 48 incorrect labels and 0 missing labels
# 0895.csv has 53 incorrect labels and 0 missing labels
# 0896.csv has 19 incorrect labels and 0 missing labels
# 0897.csv has 73 incorrect labels and 0 missing labels
# 0898.csv has 61 incorrect labels and 0 missing labels
# 0899.csv has 68 incorrect labels and 0 missing labels
# 0900.csv has 40 incorrect labels and 0 missing labels
# 0901.csv has 53 incorrect labels and 0 missing labels
# 0902.csv has 31 incorrect labels and 0 missing labels
# 0903.csv has 73 incorrect labels and 0 missing labels
# 0904.csv has 25 incorrect labels and 0 missing labels
# 0905.csv has 128 incorrect labels and 0 missing labels
# 0906.csv has 102 incorrect labels and 0 missing labels
# 0907.csv has 32 incorrect labels and 0 missing labels
# 0908.csv has 110 incorrect labels and 0 missing labels
# 0909.csv has 64 incorrect labels and 0 missing labels
# 0910.csv has 37 incorrect labels and 0 missing labels
# 0911.csv has 117 incorrect labels and 0 missing labels
# 0912.csv has 29 incorrect labels and 0 missing labels
# 0913.csv has 95 incorrect labels and 0 missing labels
# 0914.csv has 21 incorrect labels and 0 missing labels
# 0915.csv has 75 incorrect labels and 0 missing labels
# 0916.csv has 36 incorrect labels and 0 missing labels
# 0917.csv has 56 incorrect labels and 0 missing labels
# 0918.csv has 41 incorrect labels and 0 missing labels
# 0919.csv has 35 incorrect labels and 0 missing labels
# 0920.csv has 27 incorrect labels and 0 missing labels
# 0921.csv has 38 incorrect labels and 0 missing labels
# 0922.csv has 44 incorrect labels and 0 missing labels
# 0923.csv has 81 incorrect labels and 0 missing labels
# 0924.csv has 115 incorrect labels and 0 missing labels
# 0925.csv has 74 incorrect labels and 0 missing labels
# 0926.csv has 83 incorrect labels and 0 missing labels
# 0927.csv has 37 incorrect labels and 0 missing labels
# 0928.csv has 58 incorrect labels and 0 missing labels
# 0929.csv has 74 incorrect labels and 0 missing labels
# 0930.csv has 38 incorrect labels and 0 missing labels
# 0931.csv has 32 incorrect labels and 0 missing labels
# 0932.csv has 48 incorrect labels and 0 missing labels
# 0933.csv has 72 incorrect labels and 0 missing labels
# 0934.csv has 56 incorrect labels and 0 missing labels
# 0935.csv has 76 incorrect labels and 0 missing labels
# 0936.csv has 24 incorrect labels and 0 missing labels
# 0937.csv has 84 incorrect labels and 0 missing labels
# 0938.csv has 35 incorrect labels and 0 missing labels
# 0939.csv has 28 incorrect labels and 0 missing labels
# 0940.csv has 37 incorrect labels and 0 missing labels
# 0941.csv has 59 incorrect labels and 0 missing labels
# 0942.csv has 26 incorrect labels and 0 missing labels
# 0943.csv has 27 incorrect labels and 0 missing labels
# 0944.csv has 55 incorrect labels and 0 missing labels
# 0945.csv has 34 incorrect labels and 0 missing labels
# 0946.csv has 45 incorrect labels and 0 missing labels
# 0947.csv has 62 incorrect labels and 0 missing labels
# 0948.csv has 38 incorrect labels and 0 missing labels
# 0949.csv has 42 incorrect labels and 0 missing labels
# 0950.csv has 86 incorrect labels and 0 missing labels
# 0951.csv has 48 incorrect labels and 0 missing labels
# 0952.csv has 38 incorrect labels and 0 missing labels
# 0953.csv has 56 incorrect labels and 0 missing labels
# 0954.csv has 57 incorrect labels and 0 missing labels
# 0955.csv has 29 incorrect labels and 0 missing labels
# 0956.csv has 44 incorrect labels and 0 missing labels
# 0957.csv has 44 incorrect labels and 0 missing labels
# 0958.csv has 82 incorrect labels and 0 missing labels
# 0959.csv has 130 incorrect labels and 0 missing labels
# 0960.csv has 38 incorrect labels and 0 missing labels
# 0961.csv has 32 incorrect labels and 0 missing labels
# 0962.csv has 60 incorrect labels and 0 missing labels
# 0963.csv has 64 incorrect labels and 0 missing labels
# 0964.csv has 155 incorrect labels and 0 missing labels
# 0965.csv has 50 incorrect labels and 0 missing labels
# 0966.csv has 23 incorrect labels and 0 missing labels
# 0967.csv has 16 incorrect labels and 0 missing labels
# 0968.csv has 41 incorrect labels and 0 missing labels
# 0969.csv has 48 incorrect labels and 0 missing labels
# 0970.csv has 45 incorrect labels and 0 missing labels
# 0971.csv has 58 incorrect labels and 0 missing labels
# 0972.csv has 61 incorrect labels and 0 missing labels
# 0973.csv has 43 incorrect labels and 0 missing labels
# 0974.csv has 54 incorrect labels and 0 missing labels
# 0975.csv has 26 incorrect labels and 0 missing labels
# 0976.csv has 60 incorrect labels and 0 missing labels
# 0977.csv has 45 incorrect labels and 0 missing labels
# 0978.csv has 34 incorrect labels and 0 missing labels
# 0979.csv has 40 incorrect labels and 0 missing labels
# 0980.csv has 101 incorrect labels and 0 missing labels
# 0981.csv has 37 incorrect labels and 0 missing labels
# 0982.csv has 56 incorrect labels and 0 missing labels
# 0983.csv has 55 incorrect labels and 0 missing labels
# 0984.csv has 44 incorrect labels and 0 missing labels
# 0985.csv has 44 incorrect labels and 0 missing labels
# 0986.csv has 69 incorrect labels and 0 missing labels
# 0987.csv has 62 incorrect labels and 0 missing labels
# 0988.csv has 38 incorrect labels and 0 missing labels
# 0989.csv has 34 incorrect labels and 0 missing labels
# 0990.csv has 26 incorrect labels and 0 missing labels
# 0991.csv has 51 incorrect labels and 0 missing labels
# 0992.csv has 44 incorrect labels and 0 missing labels
# 0993.csv has 38 incorrect labels and 0 missing labels
# 0994.csv has 22 incorrect labels and 0 missing labels
# 0995.csv has 29 incorrect labels and 0 missing labels
# 0996.csv has 104 incorrect labels and 0 missing labels
# 0997.csv has 102 incorrect labels and 0 missing labels
# 0998.csv has 23 incorrect labels and 0 missing labels
# 0999.csv has 67 incorrect labels and 0 missing labels
# 1000.csv has 35 incorrect labels and 0 missing labels
# 1001.csv has 44 incorrect labels and 0 missing labels
# 1002.csv has 51 incorrect labels and 0 missing labels
# 1003.csv has 43 incorrect labels and 0 missing labels
# 1004.csv has 55 incorrect labels and 0 missing labels
# 1005.csv has 37 incorrect labels and 0 missing labels
# 1006.csv has 37 incorrect labels and 0 missing labels
# 1007.csv has 36 incorrect labels and 0 missing labels
# 1008.csv has 68 incorrect labels and 0 missing labels
# 1009.csv has 67 incorrect labels and 0 missing labels
# 1010.csv has 115 incorrect labels and 0 missing labels
# 1011.csv has 87 incorrect labels and 0 missing labels
# 1012.csv has 29 incorrect labels and 0 missing labels
# 1013.csv has 98 incorrect labels and 0 missing labels
# 1014.csv has 34 incorrect labels and 0 missing labels
# 1015.csv has 48 incorrect labels and 0 missing labels
# 1016.csv has 98 incorrect labels and 0 missing labels
# 1017.csv has 75 incorrect labels and 0 missing labels
# 1018.csv has 41 incorrect labels and 0 missing labels
# 1019.csv has 54 incorrect labels and 0 missing labels
# 1020.csv has 36 incorrect labels and 0 missing labels
# 1021.csv has 23 incorrect labels and 0 missing labels
# 1022.csv has 53 incorrect labels and 0 missing labels
# 1023.csv has 45 incorrect labels and 0 missing labels
# 1024.csv has 78 incorrect labels and 0 missing labels
# 1025.csv has 35 incorrect labels and 0 missing labels
# 1026.csv has 30 incorrect labels and 0 missing labels
# 1027.csv has 74 incorrect labels and 0 missing labels
# 1028.csv has 54 incorrect labels and 0 missing labels
# 1029.csv has 32 incorrect labels and 0 missing labels
# 1030.csv has 68 incorrect labels and 0 missing labels
# 1031.csv has 37 incorrect labels and 0 missing labels
# 1032.csv has 50 incorrect labels and 0 missing labels
# 1033.csv has 53 incorrect labels and 0 missing labels
# 1034.csv has 98 incorrect labels and 0 missing labels
# 1035.csv has 82 incorrect labels and 0 missing labels
# 1036.csv has 18 incorrect labels and 0 missing labels
# 1037.csv has 57 incorrect labels and 0 missing labels
# 1038.csv has 62 incorrect labels and 0 missing labels
# 1039.csv has 34 incorrect labels and 0 missing labels
# 1040.csv has 55 incorrect labels and 0 missing labels
# 1041.csv has 33 incorrect labels and 0 missing labels
# 1042.csv has 21 incorrect labels and 0 missing labels
# 1043.csv has 89 incorrect labels and 0 missing labels
# 1044.csv has 40 incorrect labels and 0 missing labels
# 1045.csv has 35 incorrect labels and 0 missing labels
# 1046.csv has 41 incorrect labels and 0 missing labels
# 1047.csv has 69 incorrect labels and 0 missing labels
# 1048.csv has 47 incorrect labels and 0 missing labels
# 1049.csv has 59 incorrect labels and 0 missing labels
# 1050.csv has 22 incorrect labels and 0 missing labels
# 1051.csv has 56 incorrect labels and 0 missing labels
# 1052.csv has 38 incorrect labels and 0 missing labels
# 1053.csv has 107 incorrect labels and 0 missing labels
# 1054.csv has 67 incorrect labels and 0 missing labels
# 1055.csv has 39 incorrect labels and 0 missing labels
# 1056.csv has 70 incorrect labels and 0 missing labels
# 1057.csv has 50 incorrect labels and 0 missing labels
# 1058.csv has 25 incorrect labels and 0 missing labels
# 1059.csv has 86 incorrect labels and 0 missing labels
# 1060.csv has 51 incorrect labels and 0 missing labels
# 1061.csv has 42 incorrect labels and 0 missing labels
# 1062.csv has 96 incorrect labels and 0 missing labels
# 1063.csv has 31 incorrect labels and 0 missing labels
# 1064.csv has 83 incorrect labels and 0 missing labels
# 1065.csv has 49 incorrect labels and 0 missing labels
# 1066.csv has 133 incorrect labels and 0 missing labels
# 1067.csv has 47 incorrect labels and 0 missing labels
# 1068.csv has 26 incorrect labels and 0 missing labels
# 1069.csv has 24 incorrect labels and 0 missing labels
# 1070.csv has 51 incorrect labels and 0 missing labels
# 1071.csv has 147 incorrect labels and 0 missing labels
# 1072.csv has 81 incorrect labels and 0 missing labels
# 1073.csv has 37 incorrect labels and 0 missing labels
# 1074.csv has 71 incorrect labels and 0 missing labels
# 1075.csv has 40 incorrect labels and 0 missing labels
# 1076.csv has 62 incorrect labels and 0 missing labels
# total label = 51268
# total incorrect = 14164
# Accuracy = 72.37263010064757
